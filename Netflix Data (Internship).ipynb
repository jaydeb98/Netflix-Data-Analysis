# %%
#Importing Necessary Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the Dataset

data = pd.read_csv(r"C:\Users\91893\Downloads\netflix1.csv")

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# # Getting Some Basic Details About the Dataset

# %%
#1. To Check the First Five Rows of the Dataset

data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
#2. To Check the Last Five Rows of the Dataset

data.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
#3. To Check the Shape of the Dataset (Rows,Columns)

data.shape
# Out:
# (8790, 10)

# %%
#4. To Check the Total Size of the Dataset

data.size
# Out:
# 87900

# %%
#5. To Check the Columns Present in the Dataset

data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
#6. To Check the Data Type of Each Column

data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
#7. To Check the Index, Columns, Data Type, and Memory at Once

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# # Data Cleaning

# %%
data[data.duplicated()] #To check for any duplicate values, existing in the dataset
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
#We see no duplicate data exist in this dataset, so we can proceed further with this.

# %%
data['date_added'] = pd.to_datetime(data['date_added']) #To convert 'date_added' column into DateTime data type

# %%
data.dtypes #To Confirm the Changes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %% [markdown]
# # Performing EDA on the Data Set

# %% [markdown]
# ## 1. Content Distribution Analysis on NETFLIX

# %%
freq = data.type.value_counts() #To Check the Type of Contents Available on Netflix and Store in the 'freq' Variable

# %%
# To Create a Figure for Both Charts
plt.figure(figsize=(12, 6))

# To Plot the Bar Chart Using Seaborn
plt.subplot(1, 2, 1)
sns.barplot(x=freq.index, y=freq.values, palette='Set2')
plt.title('Count of Movies vs TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')

# To Plot the Pie Chart Using Matplotlib
plt.subplot(1, 2, 2)
plt.pie(freq, labels=freq.index, autopct='%1.0f%%', colors=['skyblue', 'lightgreen'])
plt.title('Percentage of Movies vs TV Shows')

# Display the charts
plt.tight_layout()

# Add a super title
plt.suptitle('Netflix Content Distribution: Movies vs TV Shows', fontsize=20, y=1.05)

# Display the plots
plt.show()

# %% [markdown]
# ## 2. Rating Frequency of Movies and TV Shows on NETFLIX

# %%
rate = data['rating'].value_counts() #To check the different types of ratings and storing their counts on 'rate' variable

# %%
rate
# Out:
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %%
# To Create a Figure for Both Charts
plt.figure(figsize=(12, 6))

# To Plot the Bar Chart Using Seaborn
plt.subplot(1, 2, 1)
sns.barplot(x=rate.index, y=rate.values, palette='Set2')
plt.title('Rating on Netflix')
plt.xlabel('Rating Types')
plt.ylabel('Rating Frequency')
plt.xticks(rotation = 90)

# To Plot the Pie Chart Using Matplotlib
plt.subplot(1, 2, 2)
plt.pie(rate[:8], labels=rate[:8].index, autopct='%1.0f%%')
plt.title('Rating on Netflix')

# Display the charts
plt.tight_layout()

# Add a super title
plt.suptitle('Netflix Ratings', fontsize=20, y=1.05)

# Display the plots
plt.show()

# %% [markdown]
# ## 3. Top 10 Countries with Most Content on NETFLIX

# %%
top_ten_countries = data['country'].value_counts()[:10] #To select the top 10 countries with most content on Netflix library and store them in 'top_ten_countries' variable.

# %%
# To Create a Bar Chart
plt.figure(figsize = (9, 6))
sns.barplot(x=top_ten_countries.index, y=top_ten_countries.values, palette='plasma')
    
plt.title('Countries with Most Content')
plt.xlabel('Country')
plt.ylabel('Frequency')
plt.xticks(rotation = 45)

# Display the charts
plt.tight_layout()

# Add a super title
plt.suptitle('Top 10 Countries with Most Content', fontsize=20, y=1.05)

# Display the plots
plt.show()

# %% [markdown]
# ## 4. Monthly Release of Movies and TV Series on NETFLIX

# %%
#To Add a Separate Month Column in the Data

data['date_added'] = pd.to_datetime(data['date_added'])

# Create a 'month' column by extracting the month from the 'release_date' column
data['month'] = data['date_added'].dt.month

# %%
#To Create a Side-by-Side Bar Chart

monthly_movie_release = data[data['type']=='Movie']['month'].value_counts().sort_index()
monthly_series_release = data[data['type']=='TV Show']['month'].value_counts().sort_index()

monthly_release = pd.DataFrame({
    'Movies': monthly_movie_release,
    'Series': monthly_series_release
}).fillna(0)  # Fill missing months with 0

sns.set(style="whitegrid")

monthly_release.plot(kind='bar', figsize=(9, 6), color=sns.color_palette("pastel"))

# Customize the plot
plt.xlabel("Months")
plt.ylabel("Frequency of releases")
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=0)
plt.legend()

# Add a suptitle
plt.suptitle("Monthly Releases of Movies and TV Series on Netflix")

# Disable grid
plt.grid(False)

# To display the chart
plt.show()

# %% [markdown]
# ## 5. Yearly Release of Movies and TV Series on NETFLIX

# %%
#To Create a Line Chart

yearly_movie_release = data[data['type']=='Movie']['release_year'].value_counts().sort_index()
yearly_series_release = data[data['type']=='TV Show']['release_year'].value_counts().sort_index()

sns.set(style="whitegrid")

plt.figure(figsize=(9, 6)) 

plt.plot(yearly_movie_release.index, yearly_movie_release.values, label='Movies', color=sns.color_palette("pastel")[0], linewidth=2)
plt.plot(yearly_series_release.index, yearly_series_release.values, label='TV Shows', color=sns.color_palette("pastel")[1], linewidth=2)

# Adding labels and title
plt.xlabel("Years")
plt.ylabel("Frequency of releases")
plt.grid(True)
plt.suptitle("Yearly Releases of Movies and TV Series on Netflix")

# Adding a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## 6. Top 10 Popular Movie Genres

# %%
#To Sort Out the Top 10 Movie Genres in Netflix
popular_movie_genre = data[data.type =='Movie'].groupby("listed_in").size().sort_values(ascending=False)[:10]

popular_movie_genre
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Comedies, International Movies                      176
# dtype: int64

# %%
#To Plot the Data in Bar Chart


plt.figure(figsize=(12, 6))  # Set the figure size

# Create the bar chart
sns.barplot(x=popular_movie_genre.index, y=popular_movie_genre.values, palette="viridis")

# Adding titles and labels
plt.title('Top 10 Movie Genres on Netflix', fontsize = 16)
plt.xlabel('Movie Genres')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(axis='y')  # Add grid lines only on y-axis

# Show the bar chart
plt.show()

# %% [markdown]
# ## 7. Top 10 TV Series Genre

# %%
#To Sort Out the Top 10 TV Series in Netflix
popular_tv_series = data[data.type =='TV Show'].groupby("listed_in").size().sort_values(ascending=False)[:10]

popular_tv_series
# Out:
# listed_in
# Kids' TV                                                  219
# International TV Shows, TV Dramas                         121
# Crime TV Shows, International TV Shows, TV Dramas         110
# Kids' TV, TV Comedies                                      97
# Reality TV                                                 95
# International TV Shows, Romantic TV Shows, TV Comedies     94
# International TV Shows, Romantic TV Shows, TV Dramas       90
# Anime Series, International TV Shows                       87
# Docuseries                                                 84
# TV Comedies                                                68
# dtype: int64

# %%
#To Plot the Data in Bar Chart


plt.figure(figsize=(12, 6))  

# Create the bar chart
sns.barplot(x=popular_tv_series.index, y=popular_tv_series.values, palette="plasma")

# Adding titles and labels
plt.title('Top 10 TV Series on Netflix', fontsize = 16)
plt.xlabel('Series Genres')
plt.ylabel('Number of Series')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(axis='y')  # Add grid lines only on y-axis

# Show the bar chart
plt.show()

# %% [markdown]
# ## 8. Top 15 Directors Across NETFLIX with High Frequency of Movies and Shows

# %%
#To Sort Out the Top 15 Directors Across Netflix with High Frequency of Movies and Shows

directors = data.director.value_counts().sort_values(ascending = False)[1:16]
directors
# Out:
# Rajiv Chilaka                   20
# Alastair Fothergill             18
# Raúl Campos, Jan Suter          18
# Suhas Kadav                     16
# Marcus Raboy                    16
# Jay Karas                       14
# Cathy Garcia-Molina             13
# Youssef Chahine                 12
# Jay Chapman                     12
# Martin Scorsese                 12
# Steven Spielberg                11
# Mark Thornton, Todd Kauffman    10
# Don Michael Paul                10
# David Dhawan                     9
# Shannon Hartman                  8
# Name: director, dtype: int64

# %%
#To Plot the Data in Bar Chart

plt.figure(figsize=(12,6))

#Create the bar chart

sns.barplot(x = directors.index, y = directors.values, palette = 'inferno')

# Adding titles and labels
plt.title('Top 15 Directors on Netflix with High Frequencies of Movies and TV Shows', fontsize = 16)
plt.xlabel('Directors')
plt.ylabel('Frequency of Movies and Series')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(axis='y')  # Add grid lines only on y-axis

# Show the bar chart
plt.show()
